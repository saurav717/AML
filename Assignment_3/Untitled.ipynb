# %%
import numpy as np
import scipy.special as sp
import matplotlib.pyplot as plt

# %%
weights = np.array([1,5,100])
x = np.linspace(-5,5,200)

# %%
for i in range(0, len(weights)):
    xd = weights[i]*x
    plt.plot(x, sp.expit(xd), label = weights[i])
    
plt.show()
